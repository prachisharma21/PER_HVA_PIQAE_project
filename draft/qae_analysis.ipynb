# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
ev = np.loadtxt("e_v_dim-noise-1.dat")
evall = np.loadtxt("e_v_dim-noise-all.dat")
eref = np.loadtxt("eref_v_dim-noise-1.dat")
erefall = np.loadtxt("eref_v_dim-noise-all.dat")
sv = np.loadtxt("sref_v_dim-noise-all.dat")

# %%
[evall[i][0] for i in range(len(evall))]
# Out:
# [0.19787003970089856,
#  0.1962912314262404,
#  0.1870620770534117,
#  0.1764133870534188,
#  0.1713021097472449,
#  0.16397707235349657,
#  0.1639591175563595,
#  0.16096335404372653,
#  0.1596691746480552,
#  0.15951346330516003,
#  0.14730869492280263,
#  0.10053530696096402,
#  0.10002379597138855,
#  0.09942328571239045,
#  0.09915582530713962,
#  0.09905918079215681,
#  0.0392527123849824,
#  0.03060674862661017,
#  0.027084528542495434,
#  0.01691555131922584,
#  0.016403681616967702,
#  0.01640150175900601,
#  0.011586844766515725,
#  0.011453913072099198,
#  0.011450680098313626,
#  0.011400479997732305,
#  0.011363510159871026,
#  0.011063455741442851,
#  0.011035657589019365,
#  0.010332020713356371,
#  0.009285267056817759,
#  -0.0005705225243772816,
#  -0.015023462370180596,
#  -0.07655219567878291,
#  -0.07929843950193671]

# %%
eev= ev-(27.43 /16)

# %%
plt.plot(ev/16,marker="x")
plt.plot(eref/16,marker=".")
plt.plot([evall[i][0]/16 for i in range(len(evall))],marker="o")
plt.plot([erefall[i][0]/16 for i in range(len(evall))],marker="*")
plt.ylim([0.0001,0.2])
plt.xlim([1,49])
plt.yscale('log')
